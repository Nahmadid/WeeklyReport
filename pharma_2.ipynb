# %% [markdown]
# <a href="https://colab.research.google.com/github/Nahmadid/WeeklyReport/blob/main/pharma_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib as mpl
import optax
import sys
# import jaxopt

#@title **Doxorubicin**

import numpy as np
from scipy.integrate import odeint

#Defining the model
def Pharma(
    t,
    l0 = 0.0292 ,
    k1 = 0.0743 ,
    k2 = 0.0745,
    c  = 0.492,
):
    def func(y, t):
        return [
            l0 * y[0] - k2 * c * y[0],
            k2 * c * y[0] - k1 * y[1],
            k1 * y[1] - k1 * y[2],
            k1 * y[2] - k1 * y[3],
        ]

    # defining initial conditions for 6 state variables
    y0 = [2147.3, 0, 0, 0]
    return odeint(func, y0, t)




# t = np.arange(0, 1000, 1)[:, None]
# y = Pharma(np.ravel(t))

t_dense = jnp.linspace(0, 1000, 1001)[:, None]
y_dense_org = Pharma(np.ravel(t_dense))

scale_factor = [200,100,100,100]
y_dense = y_dense_org/scale_factor

sample_rate = 10
t_data = t_dense[::sample_rate,0:1]
Np_data = y_dense[::sample_rate,0:1]
N1_data = y_dense[::sample_rate,1:2]
N2_data = y_dense[::sample_rate,2:3]
N3_data = y_dense[::sample_rate,3:4]


data = jnp.concatenate([Np_data, N1_data, N2_data, N3_data], axis=1)
t_i  = jnp.array([[0]])
IC   = jnp.concatenate([Np_data[0:1,:], N1_data[0:1,:], N2_data[0:1,:], N3_data[0:1,:]], axis=1)
# plt.figure()
plt.scatter(t_data, data[:,0:1], alpha=0.3,label='$N_p$ sampled')
plt.plot(t_dense,y_dense[:,0],'-r',label='$N_p$')
plt.legend()
plt.figure()
plt.scatter(t_data, data[:,1:2], alpha=0.3,label='$N_1$ sampled')
plt.plot(t_dense,y_dense[:,1],'-b',label='$N_1$')
plt.legend()
plt.figure()
plt.scatter(t_data, data[:,2:3], alpha=0.3,label='$N_2$ sampled')
plt.plot(t_dense,y_dense[:,2],'-g',label='$N_2$')
plt.legend()
plt.figure()
plt.scatter(t_data, data[:,3:4], alpha=0.3,label='$N_3$ sampled')
plt.plot(t_dense,y_dense[:,3],'-g',label='$N_3$')
plt.legend()
IC
# Out:
# DeviceArray([[10.7365,  0.    ,  0.    ,  0.    ]], dtype=float32)

# %%
#@title **separate loss (na joda! oonam joda joda)**

# tmin,tmax=0.
tmin, tmax = t_dense[0,0], t_dense[-1,0]

#t = (t-np.min(t))/(np.max(t)-np.min(t))
def init_params(layers):
    keys = jax.random.split(jax.random.PRNGKey(6123), len(layers) - 1)
    params = []
    for key, n_in, n_out in zip(keys, layers[:-1], layers[1:]):
        W = jax.random.normal(key, shape=(n_in, n_out)) / jnp.sqrt(n_in) # random initialization
        B = jax.random.normal(key, shape=(n_out,))
        # params.append({'W': W, 'B': B , 'k1': 0.0 , 'k2': 0.0, 'l0': 0.0})
        params.append({'W': W, 'B': B })
    return params


# def init_params(layers):
#     keys = jax.random.split(jax.random.PRNGKey(6123), len(layers) - 1)
#     params = []
#     for key, n_in, n_out in zip(keys, layers[:-1], layers[1:]):
#         W = jax.random.normal(key, shape=(n_in, n_out)) / jnp.sqrt(n_in) # random initialization
#         B = jax.random.normal(key, shape=(n_out,))
#         params.append({'W': W, 'B': B , 'kb': 0.5 , 'kg': 0.5})
#     return params


def fwd(params,t):
  t = 0.01 * t
  X = jnp.concatenate([t],axis=1)
  *hidden,last = params
  for layer in hidden :
    X = jax.nn.tanh(X@layer['W']+layer['B'])
    # X = jnp.sin(X@layer['W']+layer['B'])
  return X@last['W'] + last['B']

def fwd_extra(params,t):
  X = jnp.concatenate([t],axis=1)
  *hidden,last = params
  for layer in hidden :
    X = jax.nn.tanh(X@layer['W']+layer['B'])
  X = X@last['W'] + last['B']
  return X



@jax.jit
def MSE(true,pred):
  return jnp.mean((true-pred)**2)

# %%
def ODE_loss(t, params, yp, y1, y2, y3, ft, gt):
    l0 = 0.0292
    k1 = 0.0743
    k2 = 0.0745

    # l0 = params[0]['l0']/10
    # k1 = params[0]['k1']/10
    # k2 = params[0]['k2']/10
    c = 0.492
    #ft = (k1 * N2 - k1 * N3)

    Np = yp(t)*scale_factor[0]
    N1 = y1(t)*scale_factor[1]
    N2 = y2(t)*scale_factor[2]
    N3 = y3(t)*scale_factor[3]

    yp_t = lambda t: jax.grad(lambda t: jnp.sum(yp(t)))(t)
    y1_t = lambda t: jax.grad(lambda t: jnp.sum(y1(t)))(t)
    y2_t = lambda t: jax.grad(lambda t: jnp.sum(y2(t)))(t)
    y3_t = lambda t: jax.grad(lambda t: jnp.sum(y3(t)))(t)

    odep = yp_t(t) - 1/scale_factor[0]*(l0 * Np - k2 * c * Np)
    ode1 = y1_t(t) - 1/scale_factor[1]* (k2 * c * Np - k1 * N1)
    ode2 = y2_t(t) - 1/scale_factor[2]* ft(t)#(k1 * N1 - k1 * N2)
    ode3 = y3_t(t) - 1/scale_factor[3]* gt(t)#(k1 * N2 - k1 * N3)


    return odep, ode1, ode2, ode3




#collocation points
N_c = 1000

t_c = jnp.linspace(tmin, tmax, N_c+1)[:, None]

def loss_fun(params,params_extra, lp, l1 ,l2 ,l3 , t_i, t_d, t_c, data_IC, data):

    yp_func = lambda t: fwd(params, t)[:, [0]]
    y1_func = lambda t: fwd(params, t)[:, [1]]
    y2_func = lambda t: fwd(params, t)[:, [2]]
    y3_func = lambda t: fwd(params, t)[:, [3]]

    ft     = lambda t: fwd_extra(params_extra, t)[:, [0]]
    gt     = lambda t: fwd_extra(params_extra, t)[:, [1]]
    # ft     = lambda t: fwd(params, t)[:, [4]]
    # gt     = lambda t: fwd(params, t)[:, [5]]

    # loss_y1, loss_y2, loss_y3 = ODE_loss(t_c, params, y1_func, y2_func, y3_func, f_t)
    loss_yp, loss_y1, loss_y2, loss_y3 = ODE_loss(t_c, params, yp_func, y1_func, y2_func, y3_func, ft,gt)

    loss_yp = lp*loss_yp
    loss_y1 = l1*loss_y1
    loss_y2 = l2*loss_y2
    loss_y3 = l3*loss_y3

    loss_odep = jnp.mean(loss_yp ** 2)
    loss_ode1 = jnp.mean(loss_y1 ** 2)
    loss_ode2 = jnp.mean(loss_y2 ** 2)
    loss_ode3 = jnp.mean(loss_y3 ** 2)


    # Compute the loss for the initial conditions
    t_i = t_i.flatten()[:,None]
    pred_IC = jnp.concatenate([yp_func(t_i),y1_func(t_i), y2_func(t_i), y3_func(t_i)],axis=1)
    loss_IC = MSE(data_IC, pred_IC)

    # Compute the loss for Y_data
    t_d    = t_d.flatten()[:,None]
    pred_d = jnp.concatenate([yp_func(t_d) ,y1_func(t_d), y2_func(t_d), y3_func(t_d)],axis=1)
    loss_data = MSE(data, pred_d)

    #loss_data = MSE(data[:,0:3], pred_d[:,0:3])
    # loss_data = MSE(data[:, [0, 3]], pred_d[:, [0, 2]])


    return loss_IC, loss_data, loss_odep, loss_ode1, loss_ode2, loss_ode3


# def loss_fun_total(params, params_extra,l1,l2, l3, t_i, t_d, t_c, data_IC, data, loss_weight):

#     loss_IC, loss_data, loss_ode1, loss_ode2, loss_ode3 = loss_fun(params, params_extra,l1,l2, l3, t_i, t_d, t_c, data_IC, data)

#     loss_total = loss_weight[0]*loss_IC+ loss_weight[1]*loss_data\
#                 + loss_weight[2]*loss_ode1+ loss_weight[3]*loss_ode2\
#                 + loss_weight[4]*loss_ode3

#     return loss_total


def loss_fun_total(params, params_extra, lp, l1,l2, l3, t_i, t_d, t_c, data_IC, data, loss_weight):

    loss_IC, loss_data, loss_odep, loss_ode1, loss_ode2, loss_ode3 = loss_fun(params, params_extra, lp ,l1,l2, l3, t_i, t_d, t_c, data_IC, data)

    loss_total = loss_weight[0]*loss_IC+ loss_weight[1]*loss_data\
                + loss_weight[2]*loss_odep+ loss_weight[3]*loss_ode1+ loss_weight[4]*loss_ode2\
                + loss_weight[5]*loss_ode3

    return loss_total






# @jax.jit
# def update(opt_state, opt_state_extra, params, params_extra, params_l1, params_l2, params_l3, opt_state_l1,opt_state_l2, opt_state_l3, t_i, t_data, t_c, IC, data, loss_weight):
#   grads=jax.grad(loss_fun_total, argnums=[0,1,2,3,4])(params, params_extra,params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data, loss_weight)

#   #Update params
#   updates, opt_state = optimizer.update(grads[0], opt_state)
#   params = optax.apply_updates(params, updates)

#   updates_extra, opt_state_extra = optimizer_ex.update(grads[1], opt_state_extra)
#   params_extra = optax.apply_updates(params_extra, updates_extra)

#   updates_l1, opt_state_l1 = optimizer.update(-grads[2], opt_state_l1)
#   params_l1 = optax.apply_updates(params_l1, updates_l1)

#   updates_l2, opt_state_l2 = optimizer.update(-grads[3], opt_state_l2)
#   params_l2 = optax.apply_updates(params_l2, updates_l2)

#   updates_l3, opt_state_l3 = optimizer.update(-grads[4], opt_state_l3)
#   params_l3 = optax.apply_updates(params_l3, updates_l3)

#   return opt_state,params,opt_state_extra,params_extra, params_l1, params_l2, params_l3, opt_state_l1,opt_state_l2, opt_state_l3




@jax.jit
def update(opt_state, opt_state_extra, params, params_extra, params_lp, params_l1, params_l2, params_l3, opt_state_lp, opt_state_l1, opt_state_l2, opt_state_l3, t_i, t_data, t_c, IC, data, loss_weight):
  grads=jax.grad(loss_fun_total, argnums=[0,1,2,3,4,5])(params,params_extra, params_lp, params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data, loss_weight)

  #Update params
  updates, opt_state = optimizer.update(grads[0], opt_state)
  params = optax.apply_updates(params, updates)

  updates_extra, opt_state_extra = optimizer_ex.update(grads[1], opt_state_extra)
  params_extra = optax.apply_updates(params_extra, updates_extra)

  updates_lp, opt_state_lp = optimizer.update(-grads[2], opt_state_lp)
  params_lp = optax.apply_updates(params_lp, updates_lp)

  updates_l1, opt_state_l1 = optimizer.update(-grads[3], opt_state_l1)
  params_l1 = optax.apply_updates(params_l1, updates_l1)

  updates_l2, opt_state_l2 = optimizer.update(-grads[4], opt_state_l2)
  params_l2 = optax.apply_updates(params_l2, updates_l2)

  updates_l3, opt_state_l3 = optimizer.update(-grads[5], opt_state_l3)
  params_l3 = optax.apply_updates(params_l3, updates_l3)

  return opt_state, opt_state_extra, params, params_extra, params_lp, params_l1, params_l2, params_l3, opt_state_lp, opt_state_l1, opt_state_l2, opt_state_l3

# %%
# construct the MLP of  4 hidden layers of 8 neurons for each layer
params = init_params([1] + [50]*6+[4])
params_extra = init_params([1] + [32]*5+[2])  # Initialize parameters for the extra neural network

optimizer = optax.adam(1e-4)
opt_state = optimizer.init(params)
optimizer_ex = optax.adam(1e-4)
opt_state_extra = optimizer_ex.init(params_extra)


keys = jax.random.split(jax.random.PRNGKey(0), 10)
lambda_p = jax.random.uniform(keys[0], shape=(N_c + 1, 1))
lambda_1 = jax.random.uniform(keys[1], shape=(N_c + 1, 1))
lambda_2 = jax.random.uniform(keys[2], shape=(N_c + 1, 1))
lambda_3 = jax.random.uniform(keys[3], shape=(N_c + 1, 1))


opt_state_lp = optimizer.init(lambda_p)
opt_state_l1 = optimizer.init(lambda_1)
opt_state_l2 = optimizer.init(lambda_2)
opt_state_l3 = optimizer.init(lambda_3)

# %%
#@title **two step training**


# start_time = time.time()
epochs_phase1 = 10000
epochs_phase2 = 150000
# loss_weight_phase1 = [1, 1, 1, 1, 1, 1]
loss_weight_phase1 = [1, 1, 0, 0, 0, 0]
loss_weight_phase2 = [1, 1, 1, 1, 1, 1]

loss_his, loss_indi_his, epoch_his = [], [], []
l0_values_list = []
k1_values_list = []
k2_values_list = []

for ep in range(epochs_phase1 + epochs_phase2 + 1):
    if ep <= epochs_phase1:
        loss_weight = loss_weight_phase1
    else:
        loss_weight = loss_weight_phase2

    opt_state,opt_state_extra, params,params_extra, params_lp,\
     params_l1, params_l2, params_l3, opt_state_lp,\
      opt_state_l1, opt_state_l2, opt_state_l3= update(opt_state,opt_state_extra, params, params_extra, lambda_p, lambda_1, lambda_2, lambda_3,\
                                                       opt_state_lp, opt_state_l1,opt_state_l2, opt_state_l3,\
                                                       t_i, t_data, t_c, IC, data, loss_weight)

    # print loss and epoch info
    if ep %(1000) ==0:
      loss_val = loss_fun_total(params, params_extra, params_lp, params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data, loss_weight)
      loss_val_individual = loss_fun(params, params_extra, params_lp, params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data)
      epoch_his.append(ep)
      loss_his.append(loss_val)
      loss_indi_his.append(loss_val_individual)

      l0_updated = 0 #params[0]['l0']/10
      k1_updated = 0 #params[0]['k1']/10
      k2_updated = 0 #params[0]['k2']/10

      print(f'Epoch={ep}, \t l0= {l0_updated} , \t k1= {k1_updated} ,\t k2={k2_updated} ,\t loss={loss_val:.2e}, \t loss_IC={loss_val_individual[0]:.2e}, \t loss_d={loss_val_individual[1]:.2e}, \t loss_ep={loss_val_individual[2]:.2e},\t loss_e1={loss_val_individual[3]:.2e}, \t loss_e2={loss_val_individual[4]:.2e}, \t loss_e3={loss_val_individual[5]:.2e}')
      # Append the values directly to the lists
      # kb_values_list.append(kb_updated)
      # kg_values_list.append(kg_updated)
      # np.savez(f'/content/drive/MyDrive/params_100_{ep}.npz', *params)

# end_time = time.time()

# running_time = end_time - start_time
# print(f"Total running time: {running_time:.2f} seconds")
# Out:
# Epoch=0, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.12e+01, 	 loss_IC=2.40e+01, 	 loss_d=7.18e+00, 	 loss_ep=2.13e-05,	 loss_e1=3.32e-03, 	 loss_e2=8.72e-05, 	 loss_e3=1.48e-05
# Epoch=1000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.78e+00, 	 loss_IC=3.44e-01, 	 loss_d=1.43e+00, 	 loss_ep=5.65e-05,	 loss_e1=4.04e-03, 	 loss_e2=1.14e-04, 	 loss_e3=1.20e-04
# Epoch=2000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.58e-01, 	 loss_IC=5.22e-03, 	 loss_d=2.53e-01, 	 loss_ep=7.78e-05,	 loss_e1=1.35e-03, 	 loss_e2=5.37e-04, 	 loss_e3=3.63e-04
# Epoch=3000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.79e-02, 	 loss_IC=1.41e-03, 	 loss_d=9.65e-02, 	 loss_ep=3.32e-05,	 loss_e1=1.14e-03, 	 loss_e2=6.08e-04, 	 loss_e3=3.10e-04
# Epoch=4000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.15e-02, 	 loss_IC=4.20e-04, 	 loss_d=4.11e-02, 	 loss_ep=1.76e-05,	 loss_e1=1.10e-03, 	 loss_e2=6.65e-04, 	 loss_e3=3.11e-04
# Epoch=5000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.66e-02, 	 loss_IC=1.32e-04, 	 loss_d=1.65e-02, 	 loss_ep=1.24e-05,	 loss_e1=1.15e-03, 	 loss_e2=6.87e-04, 	 loss_e3=3.36e-04
# Epoch=6000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=5.63e-03, 	 loss_IC=3.78e-05, 	 loss_d=5.59e-03, 	 loss_ep=1.19e-05,	 loss_e1=1.21e-03, 	 loss_e2=6.75e-04, 	 loss_e3=3.54e-04
# Epoch=7000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.54e-03, 	 loss_IC=8.67e-06, 	 loss_d=1.53e-03, 	 loss_ep=1.48e-05,	 loss_e1=1.21e-03, 	 loss_e2=6.47e-04, 	 loss_e3=3.64e-04
# Epoch=8000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.68e-04, 	 loss_IC=1.50e-06, 	 loss_d=3.67e-04, 	 loss_ep=1.81e-05,	 loss_e1=1.18e-03, 	 loss_e2=6.21e-04, 	 loss_e3=3.66e-04
# Epoch=9000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.66e-05, 	 loss_IC=2.17e-07, 	 loss_d=9.64e-05, 	 loss_ep=1.75e-05,	 loss_e1=1.16e-03, 	 loss_e2=6.08e-04, 	 loss_e3=3.69e-04
# Epoch=10000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.74e-05, 	 loss_IC=1.42e-08, 	 loss_d=2.73e-05, 	 loss_ep=1.55e-05,	 loss_e1=1.14e-03, 	 loss_e2=6.04e-04, 	 loss_e3=3.73e-04
# Epoch=11000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.28e-04, 	 loss_IC=5.27e-08, 	 loss_d=1.91e-05, 	 loss_ep=1.56e-06,	 loss_e1=5.84e-05, 	 loss_e2=2.03e-04, 	 loss_e3=1.46e-04
# Epoch=12000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.91e-04, 	 loss_IC=5.00e-05, 	 loss_d=7.26e-05, 	 loss_ep=1.32e-06,	 loss_e1=2.50e-05, 	 loss_e2=1.33e-04, 	 loss_e3=1.09e-04
# Epoch=13000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.34e-04, 	 loss_IC=1.49e-08, 	 loss_d=1.05e-05, 	 loss_ep=1.21e-06,	 loss_e1=1.59e-05, 	 loss_e2=4.88e-05, 	 loss_e3=5.76e-05
# Epoch=14000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.89e-05, 	 loss_IC=7.80e-09, 	 loss_d=8.46e-06, 	 loss_ep=1.10e-06,	 loss_e1=1.12e-05, 	 loss_e2=2.66e-05, 	 loss_e3=5.16e-05
# Epoch=15000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.01e-05, 	 loss_IC=1.05e-05, 	 loss_d=9.24e-06, 	 loss_ep=9.99e-07,	 loss_e1=8.29e-06, 	 loss_e2=1.47e-05, 	 loss_e3=4.64e-05
# Epoch=16000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.52e-05, 	 loss_IC=7.99e-06, 	 loss_d=8.48e-06, 	 loss_ep=9.20e-07,	 loss_e1=6.86e-06, 	 loss_e2=9.44e-06, 	 loss_e3=4.15e-05
# Epoch=17000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=5.69e-05, 	 loss_IC=4.62e-09, 	 loss_d=5.18e-06, 	 loss_ep=8.43e-07,	 loss_e1=6.00e-06, 	 loss_e2=8.02e-06, 	 loss_e3=3.69e-05
# Epoch=18000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.26e-05, 	 loss_IC=5.56e-09, 	 loss_d=3.75e-06, 	 loss_ep=7.58e-07,	 loss_e1=5.23e-06, 	 loss_e2=5.07e-06, 	 loss_e3=7.81e-06
# Epoch=19000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.39e-05, 	 loss_IC=1.15e-09, 	 loss_d=3.05e-06, 	 loss_ep=6.71e-07,	 loss_e1=4.69e-06, 	 loss_e2=2.51e-06, 	 loss_e3=3.02e-06
# Epoch=20000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.57e-06, 	 loss_IC=3.84e-10, 	 loss_d=2.59e-06, 	 loss_ep=6.13e-07,	 loss_e1=4.22e-06, 	 loss_e2=1.17e-06, 	 loss_e3=9.80e-07
# Epoch=21000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.15e-06, 	 loss_IC=3.17e-07, 	 loss_d=2.45e-06, 	 loss_ep=5.71e-07,	 loss_e1=3.86e-06, 	 loss_e2=5.48e-07, 	 loss_e3=3.98e-07
# Epoch=22000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.63e-06, 	 loss_IC=2.01e-10, 	 loss_d=2.06e-06, 	 loss_ep=5.36e-07,	 loss_e1=3.58e-06, 	 loss_e2=2.68e-07, 	 loss_e3=1.90e-07
# Epoch=23000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.55e-04, 	 loss_IC=1.81e-04, 	 loss_d=7.02e-05, 	 loss_ep=4.78e-07,	 loss_e1=2.97e-06, 	 loss_e2=1.42e-07, 	 loss_e3=1.22e-07
# Epoch=24000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=5.47e-06, 	 loss_IC=2.44e-09, 	 loss_d=1.73e-06, 	 loss_ep=4.65e-07,	 loss_e1=3.16e-06, 	 loss_e2=6.31e-08, 	 loss_e3=5.20e-08
# Epoch=25000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.35e-05, 	 loss_IC=6.91e-06, 	 loss_d=3.13e-06, 	 loss_ep=4.35e-07,	 loss_e1=3.00e-06, 	 loss_e2=3.61e-08, 	 loss_e3=3.25e-08
# Epoch=26000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.74e-06, 	 loss_IC=1.11e-08, 	 loss_d=1.48e-06, 	 loss_ep=4.03e-07,	 loss_e1=2.80e-06, 	 loss_e2=1.99e-08, 	 loss_e3=2.08e-08
# Epoch=27000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.52e-06, 	 loss_IC=5.04e-11, 	 loss_d=1.38e-06, 	 loss_ep=3.80e-07,	 loss_e1=2.73e-06, 	 loss_e2=1.27e-08, 	 loss_e3=1.49e-08
# Epoch=28000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.15e-04, 	 loss_IC=9.53e-05, 	 loss_d=1.67e-05, 	 loss_ep=3.45e-07,	 loss_e1=2.41e-06, 	 loss_e2=1.81e-08, 	 loss_e3=2.37e-08
# Epoch=29000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.11e-06, 	 loss_IC=5.68e-11, 	 loss_d=1.21e-06, 	 loss_ep=3.36e-07,	 loss_e1=2.55e-06, 	 loss_e2=6.78e-09, 	 loss_e3=8.97e-09
# Epoch=30000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.02e-06, 	 loss_IC=2.78e-11, 	 loss_d=1.14e-06, 	 loss_ep=3.18e-07,	 loss_e1=2.55e-06, 	 loss_e2=5.39e-09, 	 loss_e3=7.35e-09
# Epoch=31000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.78e-06, 	 loss_IC=3.50e-10, 	 loss_d=1.07e-06, 	 loss_ep=3.02e-07,	 loss_e1=2.40e-06, 	 loss_e2=4.38e-09, 	 loss_e3=6.33e-09
# Epoch=32000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.63e-06, 	 loss_IC=6.86e-11, 	 loss_d=1.01e-06, 	 loss_ep=2.86e-07,	 loss_e1=2.32e-06, 	 loss_e2=3.57e-09, 	 loss_e3=5.46e-09
# Epoch=33000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.51e-06, 	 loss_IC=1.68e-10, 	 loss_d=9.55e-07, 	 loss_ep=2.71e-07,	 loss_e1=2.28e-06, 	 loss_e2=2.99e-09, 	 loss_e3=4.78e-09
# Epoch=34000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.40e-06, 	 loss_IC=5.38e-10, 	 loss_d=9.05e-07, 	 loss_ep=2.59e-07,	 loss_e1=2.23e-06, 	 loss_e2=2.56e-09, 	 loss_e3=4.27e-09
# Epoch=35000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.07e-04, 	 loss_IC=2.96e-04, 	 loss_d=1.08e-04, 	 loss_ep=2.61e-07,	 loss_e1=2.47e-06, 	 loss_e2=4.00e-08, 	 loss_e3=5.13e-08
# Epoch=36000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.19e-06, 	 loss_IC=4.07e-11, 	 loss_d=8.19e-07, 	 loss_ep=2.38e-07,	 loss_e1=2.12e-06, 	 loss_e2=1.94e-09, 	 loss_e3=3.48e-09
# Epoch=37000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.06e-06, 	 loss_IC=1.02e-09, 	 loss_d=7.79e-07, 	 loss_ep=2.27e-07,	 loss_e1=2.05e-06, 	 loss_e2=1.70e-09, 	 loss_e3=3.13e-09
# Epoch=38000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.04e-06, 	 loss_IC=1.76e-10, 	 loss_d=7.45e-07, 	 loss_ep=2.18e-07,	 loss_e1=2.07e-06, 	 loss_e2=1.54e-09, 	 loss_e3=2.83e-09
# Epoch=39000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.90e-06, 	 loss_IC=3.01e-11, 	 loss_d=7.13e-07, 	 loss_ep=2.11e-07,	 loss_e1=1.97e-06, 	 loss_e2=1.36e-09, 	 loss_e3=2.59e-09
# Epoch=40000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.83e-06, 	 loss_IC=3.73e-11, 	 loss_d=6.81e-07, 	 loss_ep=2.02e-07,	 loss_e1=1.94e-06, 	 loss_e2=1.23e-09, 	 loss_e3=2.34e-09
# Epoch=41000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.74e-06, 	 loss_IC=1.23e-11, 	 loss_d=6.54e-07, 	 loss_ep=1.96e-07,	 loss_e1=1.89e-06, 	 loss_e2=1.12e-09, 	 loss_e3=2.16e-09
# Epoch=42000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.91e-06, 	 loss_IC=2.08e-07, 	 loss_d=6.89e-07, 	 loss_ep=1.88e-07,	 loss_e1=1.82e-06, 	 loss_e2=1.03e-09, 	 loss_e3=2.00e-09
# Epoch=43000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.59e-06, 	 loss_IC=1.04e-09, 	 loss_d=5.99e-07, 	 loss_ep=1.81e-07,	 loss_e1=1.80e-06, 	 loss_e2=9.31e-10, 	 loss_e3=1.80e-09
# Epoch=44000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.53e-06, 	 loss_IC=7.09e-10, 	 loss_d=5.76e-07, 	 loss_ep=1.74e-07,	 loss_e1=1.77e-06, 	 loss_e2=8.59e-10, 	 loss_e3=1.67e-09
# Epoch=45000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.47e-06, 	 loss_IC=4.81e-11, 	 loss_d=5.53e-07, 	 loss_ep=1.68e-07,	 loss_e1=1.74e-06, 	 loss_e2=7.99e-10, 	 loss_e3=1.56e-09
# Epoch=46000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.42e-06, 	 loss_IC=2.67e-11, 	 loss_d=5.33e-07, 	 loss_ep=1.63e-07,	 loss_e1=1.72e-06, 	 loss_e2=7.54e-10, 	 loss_e3=1.47e-09
# Epoch=47000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.36e-06, 	 loss_IC=3.39e-10, 	 loss_d=5.14e-07, 	 loss_ep=1.58e-07,	 loss_e1=1.68e-06, 	 loss_e2=7.14e-10, 	 loss_e3=1.39e-09
# Epoch=48000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.48e-06, 	 loss_IC=6.84e-08, 	 loss_d=5.06e-07, 	 loss_ep=1.50e-07,	 loss_e1=1.75e-06, 	 loss_e2=7.91e-10, 	 loss_e3=1.45e-09
# Epoch=49000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.25e-06, 	 loss_IC=1.95e-10, 	 loss_d=4.78e-07, 	 loss_ep=1.47e-07,	 loss_e1=1.62e-06, 	 loss_e2=6.31e-10, 	 loss_e3=1.26e-09
# Epoch=50000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.22e-06, 	 loss_IC=2.14e-10, 	 loss_d=4.62e-07, 	 loss_ep=1.42e-07,	 loss_e1=1.62e-06, 	 loss_e2=6.05e-10, 	 loss_e3=1.24e-09
# Epoch=51000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.27e-06, 	 loss_IC=7.78e-09, 	 loss_d=5.05e-07, 	 loss_ep=1.36e-07,	 loss_e1=1.62e-06, 	 loss_e2=6.33e-10, 	 loss_e3=1.27e-09
# Epoch=52000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.10e-06, 	 loss_IC=1.68e-10, 	 loss_d=4.30e-07, 	 loss_ep=1.34e-07,	 loss_e1=1.54e-06, 	 loss_e2=5.56e-10, 	 loss_e3=1.17e-09
# Epoch=53000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.25e-06, 	 loss_IC=1.93e-08, 	 loss_d=4.81e-07, 	 loss_ep=1.27e-07,	 loss_e1=1.62e-06, 	 loss_e2=6.45e-10, 	 loss_e3=1.33e-09
# Epoch=54000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.05e-06, 	 loss_IC=8.90e-11, 	 loss_d=4.05e-07, 	 loss_ep=1.28e-07,	 loss_e1=1.52e-06, 	 loss_e2=5.43e-10, 	 loss_e3=1.17e-09
# Epoch=55000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.99e-06, 	 loss_IC=7.90e-11, 	 loss_d=3.91e-07, 	 loss_ep=1.23e-07,	 loss_e1=1.48e-06, 	 loss_e2=5.05e-10, 	 loss_e3=1.15e-09
# Epoch=56000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.42e-06, 	 loss_IC=3.97e-07, 	 loss_d=4.08e-07, 	 loss_ep=1.17e-07,	 loss_e1=1.50e-06, 	 loss_e2=5.64e-10, 	 loss_e3=1.29e-09
# Epoch=57000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.99e-06, 	 loss_IC=1.73e-08, 	 loss_d=3.69e-07, 	 loss_ep=1.13e-07,	 loss_e1=1.49e-06, 	 loss_e2=6.07e-10, 	 loss_e3=1.35e-09
# Epoch=58000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.92e-06, 	 loss_IC=1.39e-10, 	 loss_d=3.56e-07, 	 loss_ep=1.10e-07,	 loss_e1=1.45e-06, 	 loss_e2=4.71e-10, 	 loss_e3=1.23e-09
# Epoch=59000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.81e-06, 	 loss_IC=1.61e-10, 	 loss_d=3.44e-07, 	 loss_ep=1.09e-07,	 loss_e1=1.35e-06, 	 loss_e2=4.64e-10, 	 loss_e3=1.17e-09
# Epoch=60000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.98e-06, 	 loss_IC=7.20e-08, 	 loss_d=3.42e-07, 	 loss_ep=1.03e-07,	 loss_e1=1.46e-06, 	 loss_e2=5.14e-10, 	 loss_e3=1.36e-09
# Epoch=61000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.75e-06, 	 loss_IC=3.29e-10, 	 loss_d=3.25e-07, 	 loss_ep=1.03e-07,	 loss_e1=1.32e-06, 	 loss_e2=4.43e-10, 	 loss_e3=1.20e-09
# Epoch=62000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.18e-06, 	 loss_IC=2.43e-07, 	 loss_d=4.70e-07, 	 loss_ep=9.81e-08,	 loss_e1=1.36e-06, 	 loss_e2=4.87e-10, 	 loss_e3=1.36e-09
# Epoch=63000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.75e-06, 	 loss_IC=3.09e-10, 	 loss_d=3.09e-07, 	 loss_ep=9.58e-08,	 loss_e1=1.34e-06, 	 loss_e2=4.21e-10, 	 loss_e3=1.29e-09
# Epoch=64000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.72e-06, 	 loss_IC=4.53e-12, 	 loss_d=3.01e-07, 	 loss_ep=9.33e-08,	 loss_e1=1.32e-06, 	 loss_e2=4.20e-10, 	 loss_e3=1.30e-09
# Epoch=65000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.67e-06, 	 loss_IC=2.07e-10, 	 loss_d=2.92e-07, 	 loss_ep=9.06e-08,	 loss_e1=1.29e-06, 	 loss_e2=4.11e-10, 	 loss_e3=1.31e-09
# Epoch=66000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.64e-06, 	 loss_IC=1.78e-10, 	 loss_d=2.87e-07, 	 loss_ep=8.99e-08,	 loss_e1=1.26e-06, 	 loss_e2=4.39e-10, 	 loss_e3=1.32e-09
# Epoch=67000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.60e-06, 	 loss_IC=9.11e-10, 	 loss_d=2.79e-07, 	 loss_ep=8.69e-08,	 loss_e1=1.23e-06, 	 loss_e2=4.26e-10, 	 loss_e3=1.32e-09
# Epoch=68000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.68e-04, 	 loss_IC=1.43e-04, 	 loss_d=2.30e-05, 	 loss_ep=8.55e-08,	 loss_e1=1.36e-06, 	 loss_e2=1.51e-08, 	 loss_e3=1.95e-08
# Epoch=69000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.56e-06, 	 loss_IC=4.29e-11, 	 loss_d=2.65e-07, 	 loss_ep=8.13e-08,	 loss_e1=1.21e-06, 	 loss_e2=4.19e-10, 	 loss_e3=1.37e-09
# Epoch=70000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.58e-06, 	 loss_IC=1.37e-08, 	 loss_d=2.77e-07, 	 loss_ep=7.80e-08,	 loss_e1=1.20e-06, 	 loss_e2=4.06e-10, 	 loss_e3=1.41e-09
# Epoch=71000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.50e-06, 	 loss_IC=1.09e-10, 	 loss_d=2.52e-07, 	 loss_ep=7.67e-08,	 loss_e1=1.17e-06, 	 loss_e2=4.22e-10, 	 loss_e3=1.41e-09
# Epoch=72000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.52e-06, 	 loss_IC=8.35e-11, 	 loss_d=2.47e-07, 	 loss_ep=7.44e-08,	 loss_e1=1.19e-06, 	 loss_e2=4.31e-10, 	 loss_e3=1.46e-09
# Epoch=73000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.31e-06, 	 loss_IC=1.01e-08, 	 loss_d=1.05e-06, 	 loss_ep=7.07e-08,	 loss_e1=1.18e-06, 	 loss_e2=6.62e-10, 	 loss_e3=1.61e-09
# Epoch=74000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.44e-06, 	 loss_IC=8.75e-09, 	 loss_d=2.36e-07, 	 loss_ep=6.98e-08,	 loss_e1=1.12e-06, 	 loss_e2=4.23e-10, 	 loss_e3=1.47e-09
# Epoch=75000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.45e-06, 	 loss_IC=6.74e-09, 	 loss_d=2.31e-07, 	 loss_ep=6.71e-08,	 loss_e1=1.14e-06, 	 loss_e2=4.11e-10, 	 loss_e3=1.51e-09
# Epoch=76000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.27e-06, 	 loss_IC=2.29e-06, 	 loss_d=8.39e-07, 	 loss_ep=6.60e-08,	 loss_e1=1.07e-06, 	 loss_e2=6.92e-10, 	 loss_e3=1.84e-09
# Epoch=77000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.37e-06, 	 loss_IC=2.03e-10, 	 loss_d=2.20e-07, 	 loss_ep=6.42e-08,	 loss_e1=1.08e-06, 	 loss_e2=4.39e-10, 	 loss_e3=1.51e-09
# Epoch=78000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.39e-06, 	 loss_IC=1.06e-09, 	 loss_d=2.17e-07, 	 loss_ep=6.09e-08,	 loss_e1=1.11e-06, 	 loss_e2=4.19e-10, 	 loss_e3=1.57e-09
# Epoch=79000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.43e-06, 	 loss_IC=4.32e-08, 	 loss_d=2.30e-07, 	 loss_ep=5.91e-08,	 loss_e1=1.09e-06, 	 loss_e2=4.25e-10, 	 loss_e3=1.58e-09
# Epoch=80000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.37e-06, 	 loss_IC=9.28e-09, 	 loss_d=2.07e-07, 	 loss_ep=5.73e-08,	 loss_e1=1.10e-06, 	 loss_e2=4.22e-10, 	 loss_e3=1.60e-09
# Epoch=81000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.30e-06, 	 loss_IC=3.69e-11, 	 loss_d=2.04e-07, 	 loss_ep=5.76e-08,	 loss_e1=1.03e-06, 	 loss_e2=4.58e-10, 	 loss_e3=1.55e-09
# Epoch=82000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.12e-06, 	 loss_IC=1.36e-06, 	 loss_d=4.97e-07, 	 loss_ep=5.17e-08,	 loss_e1=1.20e-06, 	 loss_e2=1.04e-09, 	 loss_e3=2.22e-09
# Epoch=83000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.27e-06, 	 loss_IC=7.71e-09, 	 loss_d=1.96e-07, 	 loss_ep=5.32e-08,	 loss_e1=1.01e-06, 	 loss_e2=4.43e-10, 	 loss_e3=1.55e-09
# Epoch=84000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.69e-06, 	 loss_IC=2.25e-06, 	 loss_d=2.86e-07, 	 loss_ep=4.98e-08,	 loss_e1=1.11e-06, 	 loss_e2=7.45e-10, 	 loss_e3=1.98e-09
# Epoch=85000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.31e-06, 	 loss_IC=6.69e-11, 	 loss_d=1.89e-07, 	 loss_ep=4.93e-08,	 loss_e1=1.07e-06, 	 loss_e2=4.33e-10, 	 loss_e3=1.60e-09
# Epoch=86000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.29e-06, 	 loss_IC=1.14e-09, 	 loss_d=1.85e-07, 	 loss_ep=4.76e-08,	 loss_e1=1.05e-06, 	 loss_e2=4.21e-10, 	 loss_e3=1.59e-09
# Epoch=87000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.24e-06, 	 loss_IC=5.71e-11, 	 loss_d=1.82e-07, 	 loss_ep=4.71e-08,	 loss_e1=1.01e-06, 	 loss_e2=4.51e-10, 	 loss_e3=1.54e-09
# Epoch=88000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.20e-06, 	 loss_IC=1.12e-11, 	 loss_d=1.79e-07, 	 loss_ep=4.67e-08,	 loss_e1=9.68e-07, 	 loss_e2=4.62e-10, 	 loss_e3=1.51e-09
# Epoch=89000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.38e-06, 	 loss_IC=1.06e-07, 	 loss_d=1.81e-07, 	 loss_ep=4.27e-08,	 loss_e1=1.04e-06, 	 loss_e2=4.56e-10, 	 loss_e3=1.58e-09
# Epoch=90000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.24e-06, 	 loss_IC=9.81e-10, 	 loss_d=1.74e-07, 	 loss_ep=4.19e-08,	 loss_e1=1.02e-06, 	 loss_e2=4.15e-10, 	 loss_e3=1.53e-09
# Epoch=91000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.14e-06, 	 loss_IC=1.56e-11, 	 loss_d=1.70e-07, 	 loss_ep=4.23e-08,	 loss_e1=9.30e-07, 	 loss_e2=4.46e-10, 	 loss_e3=1.45e-09
# Epoch=92000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.14e-04, 	 loss_IC=6.45e-05, 	 loss_d=4.85e-05, 	 loss_ep=4.10e-08,	 loss_e1=8.44e-07, 	 loss_e2=1.11e-08, 	 loss_e3=1.60e-08
# Epoch=93000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.13e-06, 	 loss_IC=1.32e-08, 	 loss_d=1.67e-07, 	 loss_ep=3.92e-08,	 loss_e1=9.09e-07, 	 loss_e2=4.26e-10, 	 loss_e3=1.40e-09
# Epoch=94000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.11e-06, 	 loss_IC=7.34e-11, 	 loss_d=1.61e-07, 	 loss_ep=3.79e-08,	 loss_e1=9.10e-07, 	 loss_e2=4.22e-10, 	 loss_e3=1.38e-09
# Epoch=95000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.08e-06, 	 loss_IC=3.67e-09, 	 loss_d=1.59e-07, 	 loss_ep=3.71e-08,	 loss_e1=8.81e-07, 	 loss_e2=4.25e-10, 	 loss_e3=1.36e-09
# Epoch=96000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.23e-06, 	 loss_IC=2.55e-09, 	 loss_d=2.32e-07, 	 loss_ep=3.45e-08,	 loss_e1=9.56e-07, 	 loss_e2=4.18e-10, 	 loss_e3=1.39e-09
# Epoch=97000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.98e-06, 	 loss_IC=4.49e-06, 	 loss_d=1.56e-06, 	 loss_ep=3.37e-08,	 loss_e1=8.96e-07, 	 loss_e2=1.05e-09, 	 loss_e3=2.20e-09
# Epoch=98000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.66e-04, 	 loss_IC=4.99e-04, 	 loss_d=1.66e-04, 	 loss_ep=3.71e-08,	 loss_e1=1.12e-06, 	 loss_e2=6.64e-08, 	 loss_e3=8.75e-08
# Epoch=99000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.04e-06, 	 loss_IC=2.70e-10, 	 loss_d=1.48e-07, 	 loss_ep=3.26e-08,	 loss_e1=8.52e-07, 	 loss_e2=4.00e-10, 	 loss_e3=1.25e-09
# Epoch=100000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.88e-06, 	 loss_IC=7.93e-07, 	 loss_d=1.74e-07, 	 loss_ep=3.07e-08,	 loss_e1=8.80e-07, 	 loss_e2=5.07e-10, 	 loss_e3=1.33e-09
# Epoch=101000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.56e-06, 	 loss_IC=8.06e-06, 	 loss_d=6.47e-07, 	 loss_ep=3.00e-08,	 loss_e1=8.22e-07, 	 loss_e2=1.29e-09, 	 loss_e3=1.84e-09
# Epoch=102000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.68e-06, 	 loss_IC=5.95e-06, 	 loss_d=7.78e-07, 	 loss_ep=2.88e-08,	 loss_e1=9.16e-07, 	 loss_e2=1.26e-09, 	 loss_e3=2.03e-09
# Epoch=103000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.07e-04, 	 loss_IC=6.37e-05, 	 loss_d=4.19e-05, 	 loss_ep=2.91e-08,	 loss_e1=9.29e-07, 	 loss_e2=1.09e-08, 	 loss_e3=1.56e-08
# Epoch=104000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.42e-04, 	 loss_IC=1.04e-04, 	 loss_d=3.76e-05, 	 loss_ep=2.91e-08,	 loss_e1=7.14e-07, 	 loss_e2=1.48e-08, 	 loss_e3=2.01e-08
# Epoch=105000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.85e-07, 	 loss_IC=2.62e-10, 	 loss_d=1.37e-07, 	 loss_ep=2.74e-08,	 loss_e1=8.19e-07, 	 loss_e2=3.84e-10, 	 loss_e3=1.11e-09
# Epoch=106000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.67e-06, 	 loss_IC=2.58e-08, 	 loss_d=6.79e-06, 	 loss_ep=2.57e-08,	 loss_e1=8.28e-07, 	 loss_e2=8.42e-10, 	 loss_e3=1.44e-09
# Epoch=107000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.87e-07, 	 loss_IC=6.84e-09, 	 loss_d=1.35e-07, 	 loss_ep=2.52e-08,	 loss_e1=8.19e-07, 	 loss_e2=3.55e-10, 	 loss_e3=1.04e-09
# Epoch=108000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.56e-05, 	 loss_IC=1.86e-05, 	 loss_d=6.03e-06, 	 loss_ep=2.37e-08,	 loss_e1=9.09e-07, 	 loss_e2=2.79e-09, 	 loss_e3=5.38e-09
# Epoch=109000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.67e-07, 	 loss_IC=1.18e-09, 	 loss_d=1.38e-07, 	 loss_ep=2.36e-08,	 loss_e1=8.03e-07, 	 loss_e2=3.44e-10, 	 loss_e3=9.70e-10
# Epoch=110000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.49e-07, 	 loss_IC=3.93e-11, 	 loss_d=1.29e-07, 	 loss_ep=2.35e-08,	 loss_e1=7.96e-07, 	 loss_e2=3.62e-10, 	 loss_e3=9.73e-10
# Epoch=111000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.09e-07, 	 loss_IC=6.65e-09, 	 loss_d=1.26e-07, 	 loss_ep=2.28e-08,	 loss_e1=7.52e-07, 	 loss_e2=3.47e-10, 	 loss_e3=9.30e-10
# Epoch=112000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.10e-07, 	 loss_IC=1.95e-11, 	 loss_d=1.24e-07, 	 loss_ep=2.21e-08,	 loss_e1=7.62e-07, 	 loss_e2=3.45e-10, 	 loss_e3=9.01e-10
# Epoch=113000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.29e-06, 	 loss_IC=2.21e-07, 	 loss_d=1.75e-07, 	 loss_ep=2.04e-08,	 loss_e1=8.77e-07, 	 loss_e2=3.65e-10, 	 loss_e3=9.32e-10
# Epoch=114000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.77e-07, 	 loss_IC=6.89e-11, 	 loss_d=1.22e-07, 	 loss_ep=2.13e-08,	 loss_e1=7.33e-07, 	 loss_e2=3.38e-10, 	 loss_e3=8.58e-10
# Epoch=115000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=9.11e-07, 	 loss_IC=2.04e-11, 	 loss_d=1.22e-07, 	 loss_ep=2.03e-08,	 loss_e1=7.68e-07, 	 loss_e2=3.43e-10, 	 loss_e3=8.36e-10
# Epoch=116000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.53e-07, 	 loss_IC=7.43e-12, 	 loss_d=1.19e-07, 	 loss_ep=1.99e-08,	 loss_e1=7.13e-07, 	 loss_e2=3.24e-10, 	 loss_e3=7.97e-10
# Epoch=117000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.88e-07, 	 loss_IC=4.77e-11, 	 loss_d=1.20e-07, 	 loss_ep=1.94e-08,	 loss_e1=7.48e-07, 	 loss_e2=3.33e-10, 	 loss_e3=7.89e-10
# Epoch=118000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.58e-07, 	 loss_IC=6.68e-10, 	 loss_d=1.17e-07, 	 loss_ep=1.84e-08,	 loss_e1=7.22e-07, 	 loss_e2=3.08e-10, 	 loss_e3=7.24e-10
# Epoch=119000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.05e-06, 	 loss_IC=9.57e-07, 	 loss_d=3.36e-07, 	 loss_ep=1.75e-08,	 loss_e1=7.36e-07, 	 loss_e2=4.89e-10, 	 loss_e3=8.91e-10
# Epoch=120000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.29e-07, 	 loss_IC=1.41e-11, 	 loss_d=1.14e-07, 	 loss_ep=1.75e-08,	 loss_e1=6.97e-07, 	 loss_e2=3.06e-10, 	 loss_e3=6.84e-10
# Epoch=121000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.58e-07, 	 loss_IC=2.57e-09, 	 loss_d=1.18e-07, 	 loss_ep=1.66e-08,	 loss_e1=7.20e-07, 	 loss_e2=2.91e-10, 	 loss_e3=6.43e-10
# Epoch=122000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.15e-07, 	 loss_IC=2.37e-10, 	 loss_d=1.12e-07, 	 loss_ep=1.66e-08,	 loss_e1=6.85e-07, 	 loss_e2=3.01e-10, 	 loss_e3=6.47e-10
# Epoch=123000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.10e-07, 	 loss_IC=3.61e-10, 	 loss_d=1.10e-07, 	 loss_ep=1.60e-08,	 loss_e1=6.82e-07, 	 loss_e2=2.95e-10, 	 loss_e3=6.15e-10
# Epoch=124000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=8.02e-07, 	 loss_IC=5.54e-11, 	 loss_d=1.09e-07, 	 loss_ep=1.55e-08,	 loss_e1=6.77e-07, 	 loss_e2=2.90e-10, 	 loss_e3=5.89e-10
# Epoch=125000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.09e-06, 	 loss_IC=1.87e-07, 	 loss_d=1.63e-07, 	 loss_ep=1.47e-08,	 loss_e1=7.27e-07, 	 loss_e2=3.22e-10, 	 loss_e3=6.16e-10
# Epoch=126000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.91e-07, 	 loss_IC=1.52e-11, 	 loss_d=1.07e-07, 	 loss_ep=1.47e-08,	 loss_e1=6.68e-07, 	 loss_e2=2.82e-10, 	 loss_e3=5.47e-10
# Epoch=127000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=5.33e-05, 	 loss_IC=4.36e-05, 	 loss_d=9.08e-06, 	 loss_ep=1.48e-08,	 loss_e1=5.87e-07, 	 loss_e2=5.58e-09, 	 loss_e3=7.48e-09
# Epoch=128000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.82e-07, 	 loss_IC=3.80e-09, 	 loss_d=1.05e-07, 	 loss_ep=1.37e-08,	 loss_e1=6.59e-07, 	 loss_e2=2.63e-10, 	 loss_e3=4.95e-10
# Epoch=129000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.49e-07, 	 loss_IC=3.42e-09, 	 loss_d=1.04e-07, 	 loss_ep=1.35e-08,	 loss_e1=6.27e-07, 	 loss_e2=2.64e-10, 	 loss_e3=4.92e-10
# Epoch=130000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.93e-07, 	 loss_IC=3.24e-11, 	 loss_d=1.04e-07, 	 loss_ep=1.32e-08,	 loss_e1=6.75e-07, 	 loss_e2=2.84e-10, 	 loss_e3=4.93e-10
# Epoch=131000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.69e-07, 	 loss_IC=8.46e-11, 	 loss_d=1.03e-07, 	 loss_ep=1.29e-08,	 loss_e1=6.52e-07, 	 loss_e2=2.70e-10, 	 loss_e3=4.76e-10
# Epoch=132000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.42e-07, 	 loss_IC=7.08e-09, 	 loss_d=1.04e-07, 	 loss_ep=1.26e-08,	 loss_e1=6.18e-07, 	 loss_e2=2.52e-10, 	 loss_e3=4.49e-10
# Epoch=133000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.37e-07, 	 loss_IC=8.98e-11, 	 loss_d=1.01e-07, 	 loss_ep=1.21e-08,	 loss_e1=6.23e-07, 	 loss_e2=2.48e-10, 	 loss_e3=4.28e-10
# Epoch=134000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.20e-07, 	 loss_IC=3.03e-09, 	 loss_d=1.01e-07, 	 loss_ep=1.19e-08,	 loss_e1=6.04e-07, 	 loss_e2=2.41e-10, 	 loss_e3=4.18e-10
# Epoch=135000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.42e-07, 	 loss_IC=4.40e-11, 	 loss_d=1.01e-07, 	 loss_ep=1.18e-08,	 loss_e1=6.29e-07, 	 loss_e2=2.47e-10, 	 loss_e3=4.22e-10
# Epoch=136000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.23e-07, 	 loss_IC=2.29e-11, 	 loss_d=9.93e-08, 	 loss_ep=1.13e-08,	 loss_e1=6.12e-07, 	 loss_e2=2.38e-10, 	 loss_e3=3.97e-10
# Epoch=137000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.77e-07, 	 loss_IC=4.08e-08, 	 loss_d=1.03e-07, 	 loss_ep=1.08e-08,	 loss_e1=6.22e-07, 	 loss_e2=2.26e-10, 	 loss_e3=3.64e-10
# Epoch=138000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.25e-07, 	 loss_IC=1.08e-09, 	 loss_d=9.83e-08, 	 loss_ep=1.06e-08,	 loss_e1=6.15e-07, 	 loss_e2=2.21e-10, 	 loss_e3=3.50e-10
# Epoch=139000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.15e-07, 	 loss_IC=5.09e-12, 	 loss_d=9.77e-08, 	 loss_ep=1.05e-08,	 loss_e1=6.06e-07, 	 loss_e2=2.29e-10, 	 loss_e3=3.63e-10
# Epoch=140000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.98e-07, 	 loss_IC=5.43e-11, 	 loss_d=9.74e-08, 	 loss_ep=1.04e-08,	 loss_e1=5.90e-07, 	 loss_e2=2.18e-10, 	 loss_e3=3.63e-10
# Epoch=141000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.39e-06, 	 loss_IC=1.32e-06, 	 loss_d=4.50e-07, 	 loss_ep=9.86e-09,	 loss_e1=6.12e-07, 	 loss_e2=4.38e-10, 	 loss_e3=5.99e-10
# Epoch=142000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.07e-06, 	 loss_IC=5.57e-08, 	 loss_d=2.74e-07, 	 loss_ep=1.01e-08,	 loss_e1=7.25e-07, 	 loss_e2=2.00e-09, 	 loss_e3=2.19e-09
# Epoch=143000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=7.20e-07, 	 loss_IC=1.12e-11, 	 loss_d=9.61e-08, 	 loss_ep=9.64e-09,	 loss_e1=6.13e-07, 	 loss_e2=2.30e-10, 	 loss_e3=3.38e-10
# Epoch=144000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.81e-06, 	 loss_IC=9.84e-07, 	 loss_d=1.97e-07, 	 loss_ep=9.17e-09,	 loss_e1=6.24e-07, 	 loss_e2=3.01e-10, 	 loss_e3=4.84e-10
# Epoch=145000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.70e-07, 	 loss_IC=2.14e-11, 	 loss_d=9.49e-08, 	 loss_ep=9.28e-09,	 loss_e1=5.65e-07, 	 loss_e2=1.97e-10, 	 loss_e3=3.20e-10
# Epoch=146000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.80e-07, 	 loss_IC=1.76e-11, 	 loss_d=9.44e-08, 	 loss_ep=9.06e-09,	 loss_e1=5.76e-07, 	 loss_e2=2.01e-10, 	 loss_e3=3.14e-10
# Epoch=147000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=5.75e-05, 	 loss_IC=3.85e-05, 	 loss_d=1.84e-05, 	 loss_ep=9.12e-09,	 loss_e1=5.27e-07, 	 loss_e2=6.60e-09, 	 loss_e3=8.49e-09
# Epoch=148000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.28e-06, 	 loss_IC=1.82e-07, 	 loss_d=4.75e-07, 	 loss_ep=8.56e-09,	 loss_e1=6.16e-07, 	 loss_e2=2.93e-10, 	 loss_e3=3.79e-10
# Epoch=149000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.56e-07, 	 loss_IC=2.46e-11, 	 loss_d=9.26e-08, 	 loss_ep=8.46e-09,	 loss_e1=5.55e-07, 	 loss_e2=1.88e-10, 	 loss_e3=2.95e-10
# Epoch=150000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.45e-07, 	 loss_IC=7.11e-11, 	 loss_d=9.16e-08, 	 loss_ep=8.18e-09,	 loss_e1=5.44e-07, 	 loss_e2=1.82e-10, 	 loss_e3=2.78e-10
# Epoch=151000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=4.06e-05, 	 loss_IC=1.82e-05, 	 loss_d=2.18e-05, 	 loss_ep=8.83e-09,	 loss_e1=5.62e-07, 	 loss_e2=5.34e-09, 	 loss_e3=5.71e-09
# Epoch=152000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.43e-07, 	 loss_IC=3.71e-11, 	 loss_d=9.13e-08, 	 loss_ep=7.99e-09,	 loss_e1=5.43e-07, 	 loss_e2=1.77e-10, 	 loss_e3=2.81e-10
# Epoch=153000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.98e-06, 	 loss_IC=1.26e-06, 	 loss_d=1.33e-07, 	 loss_ep=7.64e-09,	 loss_e1=5.80e-07, 	 loss_e2=2.67e-10, 	 loss_e3=4.31e-10
# Epoch=154000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=1.05e-06, 	 loss_IC=2.21e-08, 	 loss_d=3.09e-07, 	 loss_ep=8.21e-09,	 loss_e1=7.07e-07, 	 loss_e2=5.33e-10, 	 loss_e3=7.04e-10
# Epoch=155000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.20e-07, 	 loss_IC=2.21e-11, 	 loss_d=8.94e-08, 	 loss_ep=7.43e-09,	 loss_e1=5.23e-07, 	 loss_e2=1.66e-10, 	 loss_e3=2.60e-10
# Epoch=156000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=2.14e-04, 	 loss_IC=1.52e-04, 	 loss_d=6.22e-05, 	 loss_ep=7.89e-09,	 loss_e1=6.30e-07, 	 loss_e2=2.40e-08, 	 loss_e3=3.18e-08
# Epoch=157000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.56e-07, 	 loss_IC=2.72e-09, 	 loss_d=8.93e-08, 	 loss_ep=7.18e-09,	 loss_e1=5.57e-07, 	 loss_e2=1.77e-10, 	 loss_e3=2.42e-10
# Epoch=158000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=3.11e-05, 	 loss_IC=9.00e-06, 	 loss_d=2.15e-05, 	 loss_ep=7.63e-09,	 loss_e1=5.91e-07, 	 loss_e2=3.19e-09, 	 loss_e3=5.31e-09
# Epoch=159000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.13e-07, 	 loss_IC=6.22e-11, 	 loss_d=8.76e-08, 	 loss_ep=6.88e-09,	 loss_e1=5.18e-07, 	 loss_e2=1.62e-10, 	 loss_e3=2.40e-10
# Epoch=160000, 	 l0= 0 , 	 k1= 0 ,	 k2=0 ,	 loss=6.21e-07, 	 loss_IC=1.66e-10, 	 loss_d=8.76e-08, 	 loss_ep=6.83e-09,	 loss_e1=5.26e-07, 	 loss_e2=1.69e-10, 	 loss_e3=2.43e-10

# %%
# epochs_phase1 = 0
# epochs_phase2 = 30000
# # loss_weight_phase1 = [1, 1, 1, 1, 1, 1]
# loss_weight_phase1 = [1, 1, 0, 0, 0, 0]
# loss_weight_phase2 = [1, 1, 1, 1, 1, 1]

# loss_his, loss_indi_his, epoch_his = [], [], []
# l0_values_list = []
# k1_values_list = []
# k2_values_list = []

# for ep in range(epochs_phase1 + epochs_phase2 + 1):
#     if ep <= epochs_phase1:
#         loss_weight = loss_weight_phase1
#     else:
#         loss_weight = loss_weight_phase2

#     opt_state,opt_state_extra, params,params_extra, params_lp,\
#      params_l1, params_l2, params_l3, opt_state_lp,\
#       opt_state_l1, opt_state_l2, opt_state_l3= update(opt_state,opt_state_extra, params, params_extra, lambda_p, lambda_1, lambda_2, lambda_3,\
#                                                        opt_state_lp, opt_state_l1,opt_state_l2, opt_state_l3,\
#                                                        t_i, t_data, t_c, IC, data, loss_weight)

#     # print loss and epoch info
#     if ep %(1000) ==0:
#       loss_val = loss_fun_total(params, params_extra, params_lp, params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data, loss_weight)
#       loss_val_individual = loss_fun(params, params_extra, params_lp, params_l1, params_l2, params_l3, t_i, t_data, t_c, IC, data)
#       epoch_his.append(ep)
#       loss_his.append(loss_val)
#       loss_indi_his.append(loss_val_individual)

#       l0_updated = 0 #params[0]['l0']/10
#       k1_updated = 0 #params[0]['k1']/10
#       k2_updated = 0 #params[0]['k2']/10

#       print(f'Epoch={ep}, \t l0= {l0_updated} , \t k1= {k1_updated} ,\t k2={k2_updated} ,\t loss={loss_val:.2e}, \t loss_IC={loss_val_individual[0]:.2e}, \t loss_d={loss_val_individual[1]:.2e}, \t loss_ep={loss_val_individual[2]:.2e},\t loss_e1={loss_val_individual[3]:.2e}, \t loss_e2={loss_val_individual[4]:.2e}, \t loss_e3={loss_val_individual[5]:.2e}')
#       # Append the values directly to the lists

# %%
SAVE_FIG = False
#History of loss
font = 24
fig, ax = plt.subplots()
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=6)
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off')
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
plt.plot(epoch_his, np.asarray(loss_indi_his)[:,0], label='$loss IC$')
plt.plot(epoch_his, np.asarray(loss_indi_his)[:,1], label='$loss data$')
plt.plot(epoch_his, np.asarray(loss_indi_his)[:,2], label='$loss eqn1$')
plt.plot(epoch_his, np.asarray(loss_indi_his)[:,3], label='$loss eqn2$')
plt.plot(epoch_his, np.asarray(loss_indi_his)[:,4], label='$loss eqn3$')
plt.legend(loc="upper right",  fontsize = 24, ncol=4)
plt.legend()
ax.tick_params(axis='both', labelsize = 24)
fig.set_size_inches(w=13,h=6.5)
if SAVE_FIG:
    plt.savefig(save_results_to +'History_loss.png', dpi=300)

# %%
# !pip install jaxopt
# Out:
# Requirement already satisfied: jaxopt in /usr/local/lib/python3.10/dist-packages (0.8)
# Requirement already satisfied: jax>=0.2.18 in /usr/local/lib/python3.10/dist-packages (from jaxopt) (0.3.25)
# Requirement already satisfied: jaxlib>=0.1.69 in /usr/local/lib/python3.10/dist-packages (from jaxopt) (0.3.25)
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.10/dist-packages (from jaxopt) (1.23.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from jaxopt) (1.11.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.18->jaxopt) (3.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.18->jaxopt) (4.5.0)

# %%
# def loss_fun_total_lbfgs(params_total, t_i, t_d, t_c, data_IC, data, loss_weight):

#     params, params_extra, lp, l1,l2, l3 = params_total[0], params_total[1], params_total[2], params_total[3], params_total[4], params_total[5]

#     loss_IC, loss_data, loss_odep, loss_ode1, loss_ode2, loss_ode3 = loss_fun(params, params_extra, lp, l1 ,l2, l3, t_i, t_d, t_c, data_IC, data)


#     loss_total = loss_weight[0]*loss_IC+ loss_weight[1]*loss_data\
#                 + loss_weight[2]*loss_odep+ loss_weight[3]*loss_ode1+ loss_weight[4]*loss_ode2\
#                 + loss_weight[5]*loss_ode3

#     print(f"Loss: {loss_total}")

#     return loss_total

# %%
# print("L-BFGS optimizer begins")
# import jaxopt
# loss_weight = [1, 1, 1, 1, 1 ,1]

# params_total = []
# params_total.append(params)
# params_total.append(params_extra)
# params_total.append(params_lp)
# params_total.append(params_l1)
# params_total.append(params_l2)
# params_total.append(params_l3)


# l_fun = lambda p_l: loss_fun_total_lbfgs(p_l, t_i, t_data, t_c, IC, data, loss_weight)

# optimizer_lbfgs = jaxopt.LBFGS(fun=l_fun, history_size=100,  verbose=True, maxiter=1000)
# sol = optimizer_lbfgs.run(params_total)
# params_total = sol.params

# %%
# params = params_total[0]
# params_extra = params_total[1]

# %%
# # import pandas as pd
# with np.load('/content/drive/MyDrive/params_100_62000.npz', allow_pickle=True) as data:
#     loaded_params = [dict(data[name].item()) for name in data.files]

# with np.load('/content/drive/MyDrive/params_extra_100_62000.npz', allow_pickle=True) as data:
#     loaded_params_extra = [dict(data[name].item()) for name in data.files]



pred = fwd(params,t_dense)
plt.plot(t_dense,y_dense[:,0],'r',label='$N_p$')
plt.plot(t_dense,pred[:,0],'--k',label='SBINN',linewidth=2)

plt.legend()
plt.figure()
plt.plot(t_dense,y_dense[:,1],'b',label='$N_1$')
plt.plot(t_dense,pred[:,1],'--k',label='SBINN',linewidth=2)

plt.legend()
plt.figure()
plt.plot(t_dense,y_dense[:,2],label='$N_2$')
plt.plot(t_dense,pred[:,2],'--k',label='SBINN',linewidth=2)

plt.legend()
plt.figure()
plt.plot(t_dense,y_dense[:,3],'r',label='$N_3$')
plt.plot(t_dense,pred[:,3],'--k',label='SBINN',linewidth=2)
plt.legend()


# # f_t =fwd(loaded_params_extra, t_dense)
# f_t =fwd_extra(loaded_params_extra, t_dense)*10
# G_pred = pred[:,0:1]*10
# B_pred = pred[:,1:2]*10
# df_f = pd.DataFrame({"t": np.ravel(t_dense),"G": np.ravel(G_pred), "B": np.ravel(B_pred), "ft": np.ravel(f_t) })
# df_f.to_csv("/content/drive/MyDrive/ft_combined_100.csv", index=False)

# # df_g = pd.DataFrame({"t": np.ravel(t_dense),"Ip": np.ravel(Ip_pred), "Ii": np.ravel(Ii_pred), "gt": np.ravel(g_t_pred) })
# # df_g.to_csv("/content/drive/MyDrive/gt_250_19.csv", index=False)


# plt.legend()
plt.figure()



# kg = 0.72
# kb = 0.15
# G0 = 0.1

# # Calculate f_t using the provided equations
# f_t_analytical = kg * y_dense[:, 0] - kb * y_dense[:, 1]*10
# f_t_neural = fwd_extra(loaded_params_extra, t_dense)[:, 0]*10

# f_t_err = f_t_analytical - f_t_neural
# # F_SR= 0.739 *y_dense[:, 0]- 0.141* y_dense[:, 1]
# F_SR= 0.712 *y_dense[:, 0]#- 0.141* y_dense[:, 1]
# # f_t_neural = fwd_extra(loaded_params_extra, t_dense)[:, 0]
# # Plot both f_t values
# plt.plot(t_dense, f_t, label='$f(t)$ (exact) = 0.72 G + 0.15 B')
# plt.plot(t_dense, f_t_neural,'r',linewidth=2, label='f(t) PINN', alpha=0.3)
# # plt.plot(t_dense, f_t_err,'--b',linewidth=2, label='f(t) PINN', alpha=0.3)
# # plt.plot(t_dense, F_SR ,'--k', label='$f(t)$ (Symbolic Regression)= 0.739 G + 0.141 B ')
# plt.grid()
# plt.xlabel('t')
# plt.ylabel('$f(t)$')
# plt.title('Result of 100 data points')
# plt.legend()
# plt.show()



# # plt.plot(T,fwd(params_extra,T.reshape(-1,1)),'--k',label='NN[G]',linewidth=2)

# plt.legend()

# %%
l0 = 0.0292
k1 = 0.0743
k2 = 0.0745
N1 = pred[:,1]*scale_factor[1]
N2 = pred[:,2]*scale_factor[2]
N3 = pred[:,3]*scale_factor[3]
# l0 = params[0]['l0']/10
# k1 = params[0]['k1']/10
# k2 = params[0]['k2']/10
c = 0.492
ft=(k1 * N1 - k1 * N2)
gt=(k1 * N2 - k1 * N3)

ft_NN = fwd_extra(params_extra, t_dense)[:,0]
# ft_NN = pred[:, 4]
plt.figure()
plt.plot(t_dense,ft,'r',label='$f_t$')
plt.plot(t_dense, ft_NN,'--k',label='SBINN',linewidth=2)
plt.legend()

# gt_NN = pred[:, 5]
gt_NN = fwd_extra(params_extra, t_dense)[:,1]
plt.figure()
plt.plot(t_dense,gt,'r',label='$g_t$')
plt.plot(t_dense, gt_NN,'--k',label='SBINN',linewidth=2)
plt.legend()
